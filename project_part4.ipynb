# %%
from google.colab import files
auto = files.upload()
# Out:
#      <input type="file" id="files-9bc19f69-97f5-423d-8b31-04286ff7da9a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9bc19f69-97f5-423d-8b31-04286ff7da9a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

def load_and_preprocess_data():
    """
    Load data from the already uploaded file, handle missing values, and apply preprocessing.
    """
    filename = 'Electric_Vehicle_Population_Data.csv'
    data = pd.read_csv(filename)
    data = data[['Make', 'Model', 'Model Year', 'Electric Vehicle Type', 'Clean Alternative Fuel Vehicle (CAFV) Eligibility']].copy()
    data = data[data['Clean Alternative Fuel Vehicle (CAFV) Eligibility'] != 'Eligibility unknown as battery range has not been researched']
    data.dropna(inplace=True)
    return data.astype(str)

def create_graphics(data):
    """
    Create scatterplots and histograms showcasing initial findings on the data.
    """
    # Setting seaborn style
    sns.set(style="whitegrid", font_scale=1.2)

    # Figure 1: Scatterplot - Model Year vs Electric Vehicle Type (Proportion)
    sorted_years = sorted(data['Model Year'].unique(), reverse=True)
    plt.figure(figsize=(10, 6))
    sns.countplot(x='Model Year', hue='Clean Alternative Fuel Vehicle (CAFV) Eligibility', data=data, palette='viridis', order=sorted_years)
    plt.title('Figure 1: Model Year vs. Clean Alternative Fuel Vehicle (CAFV) Eligibility', fontsize=16)
    plt.xlabel('Model Year', fontsize=14)
    plt.ylabel('Count', fontsize=14)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

    # Figure 2: Boxplot - Model Year Distribution by Electric Vehicle Type
    plt.figure(figsize=(10, 8))
    sns.boxplot(x='Clean Alternative Fuel Vehicle (CAFV) Eligibility', y='Model Year', data=data, palette='coolwarm')
    plt.title('Figure 2: Model Year Distribution by Clean Alternative Fuel Vehicle (CAFV) Eligibility', fontsize=16)
    plt.xlabel('Clean Alternative Fuel Vehicle (CAFV) Eligibility', fontsize=14)
    plt.ylabel('Model Year', fontsize=14)
    plt.xticks(rotation=30)
    plt.tight_layout()
    plt.show()




def create_additional_graphics(data):
    """
    Create additional visualizations showcasing more insights into the data.
    """
    # Figure 3: Histogram - Distribution of Vehicles by Make
    plt.figure(figsize=(12, 6))
    make_counts = data['Make'].value_counts().head(10)  # Taking top 10 makes for clarity
    sns.barplot(x=make_counts.index, y=make_counts.values, palette='inferno')
    plt.title('Figure 3: Top 10 Vehicle Makes Distribution', fontsize=16)
    plt.xlabel('Vehicle Make', fontsize=14)
    plt.ylabel('Number of Vehicles', fontsize=14)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

    # Figure 4: Scatterplot - Model Year vs Make (Top 10 Makes)
    sorted_years = sorted(data['Model Year'].unique(), reverse=True)
    plt.figure(figsize=(12, 6))
    top_makes = data['Make'].value_counts().head(10).index
    filtered_data = data[data['Make'].isin(top_makes)]
    sns.countplot(x='Model Year', hue='Make', data=filtered_data, palette='tab10', order=sorted_years)
    plt.title('Figure 4: Model Year vs. Top 10 Vehicle Makes', fontsize=16)
    plt.xlabel('Model Year', fontsize=14)
    plt.ylabel('Count', fontsize=14)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

    # Figure 5: Pie chart - Proportion of Electric Vehicle Types
    plt.figure(figsize=(8, 8))
    type_counts = data['Clean Alternative Fuel Vehicle (CAFV) Eligibility'].value_counts()
    plt.pie(type_counts, labels=type_counts.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('pastel'))
    plt.title('Figure 5: Proportion of Clean Alternative Fuel Vehicle (CAFV) Eligibility', fontsize=16)
    plt.tight_layout()
    plt.show()


    # Figure 6: Histogram - Electric Vehicle Type Distribution
    plt.figure(figsize=(10, 8))
    sns.countplot(x='Clean Alternative Fuel Vehicle (CAFV) Eligibility', data=data, palette='magma')
    plt.title('Figure 6: Clean Alternative Fuel Vehicle (CAFV) Eligibility Distribution', fontsize=16)
    plt.xlabel('Clean Alternative Fuel Vehicle (CAFV) Eligibility', fontsize=14)
    plt.ylabel('Count', fontsize=14)
    plt.xticks(rotation=30)
    plt.tight_layout()
    plt.show()

def main():
    # Load and preprocess the data
    data = load_and_preprocess_data()
    if data is None:
        return

    # Create graphics showcasing initial findings
    create_graphics(data)

    # Create additional graphics showcasing more insights
    create_additional_graphics(data)

# Run the main program
if __name__ == "__main__":
    main()

# %% [markdown]
# According to the results in Figure 1 and Figure 2, it is found that:
#
# **CAFV eligibility trends:**
#
# As can be seen in Figure 1, more vehicles in the newer model category qualify as Clean Alternative Fuel Vehicles (CAFVs). Especially in 2018 and 2020, the number of eligible vehicles increased significantly and reached a peak.
# Among older models, there are more vehicles that are not eligible for CAFV, which may be related to the fact that the battery capacity and technology of these models do not meet the requirements.
#
# **Differences in year distribution:**
#
# The boxplot in Figure 2 further illustrates the distribution of model years that are and are not CAFV eligible. Vehicles eligible for CAFV are mainly concentrated from 2018 to 2020, are more concentrated and are newer.
# The vehicle years that are not eligible for CAFV are spread over a wide range and include earlier model years. These models are generally older, suggesting the reason for ineligibility may be related to early technology limitations.
#
# **Initial Finding:**
#
# Comparing Figures 1 and 2, newer models are more likely to qualify as CAFV. This reflects the progress in clean energy vehicle technology in recent years.

# %% [markdown]
# According to the results in Figure 3 and Figure 4, it is found that:
#
# **Figure 3: Distribution of top 10 EV brands**
#
# In Figure 3, it can be seen that Tesla clearly dominates the electric vehicle market with far more vehicles than any other brand. The brands that follow closely are Nissan and Chevrolet, which shows that these two brands are competitive in the clean fuel vehicle market. This indicates Tesla's dominant position in the clean alternative fuel vehicle market, which may be related to its improving battery technology and market acceptance.
#
# **Figure 4: Distribution of top 10 brands by model year**
#
# Figure 4 illustrates the distribution of the top 10 brands by model year, particularly dominated by Tesla in 2018 and 2020, showing a significant increase in the number of their vehicles in these years. The other brands are relatively more evenly distributed across years, but Tesla still leads significantly in recent years in terms of sales and number of eligible models. This may indicate Tesla's success in launching CAFV-compliant models in recent years, particularly its leadership in clean energy technology.
#
# **Initial Finding:**
#
# Tesla leads the electric vehicle market, particularly in recent model years, with a strong focus on producing CAFV-eligible vehicles. Other brands like Nissan and Chevrolet also play significant roles but are more evenly spread across model years. Tesla’s concentration in recent years underscores its commitment to clean energy technology and positions it as a major contributor to the CAFV market.

# %% [markdown]
# According to the results in Figure 5 and Figure 6, it is found that:
#
# **Figure 5：CAFV Eligibility Proportion:**
#
# Figure 5 illustrates the proportion of vehicles that are eligible versus ineligible for CAFV. About 76.8% of the vehicles meet CAFV eligibility, reflecting strong alignment with clean fuel requirements across the majority of electric vehicles. However, 23.2% of vehicles are not eligible due to limited battery range, likely tied to older model technology constraints.
#
# **Figure 6：CAFV Eligibility Distribution:**
#
# The bar chart in Figure 6 provides a clear view of the distribution of vehicles based on CAFV eligibility. The number of vehicles meeting CAFV eligibility criteria is significantly higher than those that do not, underscoring a market trend toward clean fuel vehicles. This distribution further emphasizes the automotive industry’s focus on meeting CAFV standards, supported by advancements in battery technology and regulatory incentives.
#
# **Initial Finding:**
#
# The majority of electric vehicles (76.8%) meet CAFV eligibility requirements, reflecting the industry’s focus on clean alternative fuel standards. However, a smaller portion (23.2%) is not eligible, often due to battery range limitations found in older models. This distribution highlights both the progress in clean energy adoption and the ongoing challenges associated with earlier electric vehicle technologies.
